# %% [markdown]
# # M4- W4 Prpject

# %% [markdown]
# # Investigate the Airbnb

# %% [markdown]
# # Business Scope : Advice from Airbnb to Host
#
# How Airbnb can help host to rent their houses in best price.

# %%
#importing the necessary libraries
import pandas as pd
import numpy as np
import statsmodels.api as sm

import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns

import re

import warnings
warnings.filterwarnings("ignore")

# %%
# reading the csv file
CS=pd.read_csv('calendar_summary.csv')

# %%
# reading the csv file
L=pd.read_csv('listings.csv')

# %%
# reading the csv file
LS=pd.read_csv('listings_summary.csv')

# %%
#check the head
CS.head()
# Out:
#    listing_id        date available price
# 0        2015  2019-09-10         f   NaN
# 1        2015  2019-09-09         f   NaN
# 2        2015  2019-09-08         f   NaN
# 3        2015  2019-09-07         f   NaN
# 4        2015  2019-09-06         f   NaN

# %%
#change the type of date into datetime and save it in new column by name 'Date'
CS['date']=pd.to_datetime(CS['date'])

# %%
# calculate the sum of the none value
CS.price.isna().sum()
# Out:
# 6430639

# %%
# remover the $ sign
CS['price']=CS['price'].str.replace('$','')

# %%
# change price to numeric
CS['price']=pd.to_numeric(CS['price'],errors='coerce')

# %%
# Filter CS by true cases: where hose is rent (price available)
CST = CS[CS['available'] == 't']

# %%
 #create the new column data restructuring the original Date column with pd.to_datetime
#calculate day of year
CST['day'] = CS['date'].dt.dayofyear
CST['month']=CS['date'].dt.month
CST['week']=CS['date'].dt.weekofyear
# Create year
CST['Year'] = CS['date'].dt.year

#to divide by season it's better to use the day of the year instead of the months
spring = range(80, 172)
summer = range(172, 264)
fall = range(264, 355)
# winter = everything else

daje = []
for i in CST['day']:
    if i in spring:
        season = 'spring'
    elif i in summer:
        season = 'summer'
    elif i in fall:
        season = 'fall'
    else:
        season = 'winter'
    daje.append(season)   

#add the resulting column to the dataframe (after transforming it as a Series)
CST['season']= pd.Series(daje)

# %%
# Suplots of time of the year 
sns.set_style('darkgrid')
f, axes = plt.subplots(2, figsize = (15,15))


# Plot [0,0]
#making the bar chart for number of selling based on season
sns.countplot(CST['season'], ax = axes[0])
axes[0].set_xlabel('Season')
axes[0].set_ylabel('Count')
axes[0].set_title('The number of rent in each season of year')

# Plot [0,1]
#making the bar chart for number of sell based on month
sns.countplot(CST['month'], ax = axes[1])
axes[1].set_xlabel('Month')
axes[1].set_ylabel('Count')
axes[1].set_title('The number of rent in each month of year')
# Out:
# Text(0.5, 1.0, 'The number of rent in each month of year')

# %%
#calculate the mean price based on month, week, year, season
price_behave=CST[['Year','month','week','season','price']]
price_year_mean=price_behave.groupby('Year').mean()
price_month_mean=price_behave.groupby('month').mean()
price_week_mean=price_behave.groupby('week').mean()
price_season_mean=price_behave.groupby('season').mean()

# %%
# Suplots of time of the year 
sns.set_style('darkgrid')
f, axes = plt.subplots(2,2, figsize = (15,15))

# Plot [0,0]
# making bar chart for the number of selling in the year
#sns.countplot(price_year_mean['price'], ax = axes[0, 0])
price_year_mean['price'].plot(kind='bar',ax = axes[0, 0])
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Count')
axes[0,0].set_title('Average price of rent in year')

# Plot [0,1]
#making the bar chart for number of selling based on season
#sns.countplot(price_season_mean['price'], ax = axes[0, 1])
price_month_mean['price'].plot(kind='bar',ax = axes[0, 1])
axes[0,1].set_xlabel('Month')
axes[0,1].set_ylabel('Count')
axes[0,1].set_title('Average price of rent in each month of year')

# Plot [1,0]
#making the bar chart for number of sell based on month
#sns.countplot(price_month_mean['price'], ax = axes[1, 0])
price_week_mean['price'].plot(kind='bar',ax = axes[1, 0])
axes[1,0].set_xlabel('Week')
axes[1,0].set_ylabel('Count')
axes[1,0].set_title('Average price of rent in each week of year')

# Plot [1,1]
#making the bar chart for nuber of  sell by weeks.
#sns.countplot(price_week_mean['price'], ax = axes[1, 1])
price_season_mean['price'].plot(kind='bar',ax = axes[1, 1])
axes[1,1].set_xlabel('Season')
axes[1,1].set_ylabel('Count')
axes[1,1].set_title('Average price of rent in each season of year')
# Out:
# Text(0.5, 1.0, 'Average price of rent in each season of year')

# %% [markdown]
# # Looking for features that directly can increase the price

# %%
# check the dataset 
LS.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2015  https://www.airbnb.com/rooms/2015  20181107122246   2018-11-07
# 1  2695  https://www.airbnb.com/rooms/2695  20181107122246   2018-11-07
# 2  3176  https://www.airbnb.com/rooms/3176  20181107122246   2018-11-07
# 3  3309  https://www.airbnb.com/rooms/3309  20181107122246   2018-11-07
# 4  7071  https://www.airbnb.com/rooms/7071  20181107122246   2018-11-07
#
#                                                name  \
# 0  Berlin-Mitte Value! Quiet courtyard/very central
# 1                Prenzlauer Berg close to Mauerpark
# 2                   Fabulous Flat in great Location
# 3                 BerlinSpot Schöneberg near KaDeWe
# 4                  BrightRoom with sunny greenview!
#
#                                              summary  \
# 0  Great location!  30 of 75 sq meters. This wood...
# 1                                                NaN
# 2  This beautiful first floor apartment  is situa...
# 3  First of all: I prefer short-notice bookings. ...
# 4  Cozy and large room in the beautiful district ...
#
#                                                space  \
# 0  A+++ location! This „Einliegerwohnung“ is an e...
# 1  In the summertime we are spending most of our ...
# 2  1st floor (68m2) apartment on Kollwitzplatz/ P...
# 3  Your room is really big and has 26 sqm, is ver...
# 4  The BrightRoom is an approx. 20 sqm (215ft²), ...
#
#                                          description experiences_offered  \
# 0  Great location!  30 of 75 sq meters. This wood...                none
# 1  In the summertime we are spending most of our ...                none
# 2  This beautiful first floor apartment  is situa...                none
# 3  First of all: I prefer short-notice bookings. ...                none
# 4  Cozy and large room in the beautiful district ...                none
#
#                                neighborhood_overview        ...          \
# 0  It is located in the former East Berlin area o...        ...
# 1                                                NaN        ...
# 2  The neighbourhood is famous for its variety of...        ...
# 3  My flat is in the middle of West-Berlin, direc...        ...
# 4  Great neighborhood with plenty of Cafés, Baker...        ...
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                t     NaN                NaN                f
# 1                t     NaN                NaN                f
# 2                t     NaN                NaN                t
# 3                t     NaN                NaN                f
# 4                t     NaN                NaN                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     flexible
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f                     moderate
#
#    require_guest_profile_picture require_guest_phone_verification  \
# 0                              f                                f
# 1                              f                                f
# 2                              f                                f
# 3                              f                                f
# 4                              f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               4               3.76
# 1                               1               1.42
# 2                               1               1.25
# 3                               1               0.39
# 4                               1               1.75
#
# [5 rows x 96 columns]

# %%
#check the number of records and columns
LS.shape
# Out:
# (22552, 96)

# %% [markdown]
# # Data cleaning for specific columns we need to use

# %%
# define the columns we want to keep
columns_to_keep = ['id', 'host_has_profile_pic', 'neighbourhood_group_cleansed', 
                   'latitude', 'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',  
                   'bedrooms', 'amenities', 'square_feet', 'price', 'cleaning_fee', 
                   'security_deposit', 'extra_people', 'guests_included',  
                   'instant_bookable']

#set id as index
LS_new = LS[columns_to_keep].set_index('id')
print("The dataset has {} rows and {} columns - after dropping irrelevant columns.".format(*LS_new.shape))
# Out:
# The dataset has 22552 rows and 17 columns - after dropping irrelevant columns.

# %%
#check some columns we need to analysis
LS_new[['price', 'amenities', 'square_feet', 'bedrooms']].head()
# Out:
#        price                                          amenities  square_feet  \
# id
# 2015  $60.00  {TV,"Cable TV",Wifi,Kitchen,Gym,Heating,"Famil...          NaN
# 2695  $17.00  {Wifi,Kitchen,Elevator,Heating,Washer,Essentia...          NaN
# 3176  $90.00  {Internet,Wifi,Kitchen,"Buzzer/wireless interc...        720.0
# 3309  $26.00  {Internet,Wifi,"Pets allowed","Pets live on th...          0.0
# 7071  $42.00  {Wifi,Heating,"Family/kid friendly",Essentials...          NaN
#
#       bedrooms
# id
# 2015       1.0
# 2695       1.0
# 3176       1.0
# 3309       1.0
# 7071       1.0

# %%
# checking Nan's in "price" column
LS_new.price.isna().sum()
# Out:
# 0

# %%
LS_new.square_feet.isna().sum()
# Out:
# 22106

# %%
LS_new.square_feet.fillna('unknown', inplace=True)
LS_new.square_feet.isna().sum()
# Out:
# 0

# %%
# remove $ and , 
LS_new.price = LS_new.price.astype(str).str.replace('$', '').str.replace(',', '').astype(float)

# %%
#let see price in details
LS_new['price'].describe()
# Out:
# count    22552.000000
# mean        67.143668
# std        220.266210
# min          0.000000
# 25%         30.000000
# 50%         45.000000
# 75%         70.000000
# max       9000.000000
# Name: price, dtype: float64

# %%
#create box plot for find the outliers
Boxprice = dict(markerfacecolor='r', markeredgecolor='r', marker='.')
LS_new['price'].plot(kind='box', xlim=(0, 1000), vert=False, flierprops=Boxprice, figsize=(16,2));

# %%
#remove upper than 600 and see the distribution
LS_new = LS_new[LS_new["price"] < 600]

# %%
#plot distribution
LS_new["price"].hist(bins = 30)
LS_new["price"].std()
# Out:
# 46.63081884451465

# %%
# remove upper than 300
LS_new = LS_new[LS_new["price"] < 300]

# %%
# checking the distribution again
LS_new["price"].hist(bins = 30)
LS_new["price"].std()
# Out:
# 38.162050086030256

# %%
#cleaning the bedroom column and change it to str type
LS_new["bedrooms"] = LS_new["bedrooms"].astype("str")

# %%
#LS_new["bedrooms"] = LS_new["bedrooms"].fillna(0.5) #these are studios
LS_new["bedrooms"] = LS_new["bedrooms"].fillna('studio') #these are studios

# %%
LS_new["bedrooms"]=pd.to_numeric(LS_new["bedrooms"],errors='coerce')

# %%
LS_new["square_feet"]=pd.to_numeric(LS_new["square_feet"],errors='coerce')

# %%
LS_new.head(100)
# Out:
#        host_has_profile_pic neighbourhood_group_cleansed   latitude  \
# id
# 2015                      t                        Mitte  52.534537
# 2695                      t                       Pankow  52.548513
# 3176                      t                       Pankow  52.534996
# 3309                      t       Tempelhof - Schöneberg  52.498855
# 7071                      t                       Pankow  52.543157
# 9991                      t                       Pankow  52.533031
# 14325                     t                       Pankow  52.547846
# 16401                     t     Friedrichshain-Kreuzberg  52.510514
# 16644                     t     Friedrichshain-Kreuzberg  52.504792
# 17409                     t                       Pankow  52.529071
# 17904                     t                     Neukölln  52.495476
# 20858                     t                       Pankow  52.536952
# 21869                     t     Friedrichshain-Kreuzberg  52.502733
# 22415                     t     Friedrichshain-Kreuzberg  52.494851
# 22677                     t                        Mitte  52.534348
# 23834                     t     Friedrichshain-Kreuzberg  52.489714
# 24569                     t                       Pankow  52.530791
# 25653                     t                       Pankow  52.530259
# 26543                     t                       Pankow  52.544062
# 28156                     t                       Pankow  52.546719
# 28268                     t     Friedrichshain-Kreuzberg  52.513385
# 28711                     t                     Neukölln  52.486106
# 29279                     t                       Pankow  52.541788
# 30295                     t                       Pankow  52.545967
# 31440                     t                       Pankow  52.543089
# 33043                     t                        Mitte  52.521418
# 35642                     t                       Pankow  52.549361
# 36480                     t         Charlottenburg-Wilm.  52.519677
# 37004                     t       Tempelhof - Schöneberg  52.493389
# 37052                     t                        Mitte  52.538220
# ...                     ...                          ...        ...
# 83183                     t                       Pankow  52.536773
# 83568                     t                       Pankow  52.544849
# 83614                     t                       Pankow  52.546220
# 85560                     t                        Mitte  52.531815
# 86514                     t     Friedrichshain-Kreuzberg  52.498208
# 87549                     t     Friedrichshain-Kreuzberg  52.496156
# 89102                     t                       Pankow  52.540529
# 91290                     t                     Neukölln  52.490038
# 106290                    t     Friedrichshain-Kreuzberg  52.497271
# 106331                    t                       Pankow  52.533703
# 107968                    t       Tempelhof - Schöneberg  52.498548
# 109658                    t     Friedrichshain-Kreuzberg  52.524265
# 111579                    t                        Mitte  52.527201
# 114763                    t       Tempelhof - Schöneberg  52.488050
# 115576                    t                       Pankow  52.581503
# 116832                    t     Friedrichshain-Kreuzberg  52.490944
# 117649                    t     Friedrichshain-Kreuzberg  52.500044
# 121888                    t     Friedrichshain-Kreuzberg  52.518177
# 125349                    t           Treptow - Köpenick  52.451052
# 127708                    t                        Mitte  52.519649
# 128827                    t     Friedrichshain-Kreuzberg  52.509483
# 135097                    t       Tempelhof - Schöneberg  52.500892
# 138955                    t     Friedrichshain-Kreuzberg  52.490975
# 139769                    t                        Mitte  52.528106
# 143605                    t                     Neukölln  52.476778
# 145249                    t     Friedrichshain-Kreuzberg  52.518192
# 147946                    t                       Pankow  52.548549
# 149849                    t                        Mitte  52.529817
# 151249                    t     Friedrichshain-Kreuzberg  52.496779
# 153015                    t                       Pankow  52.547146
#
#         longitude property_type        room_type  accommodates  bathrooms  \
# id
# 2015    13.402557    Guesthouse  Entire home/apt             3        1.0
# 2695    13.404553     Apartment     Private room             2        1.0
# 3176    13.417579     Apartment  Entire home/apt             4        1.0
# 3309    13.349065     Apartment     Private room             2        1.0
# 7071    13.415091     Apartment     Private room             2        1.0
# 9991    13.416047     Apartment  Entire home/apt             7        2.5
# 14325   13.405562     Apartment  Entire home/apt             2        1.0
# 16401   13.457850     Apartment     Private room             2        1.0
# 16644   13.435102     Apartment  Entire home/apt             5        1.0
# 17409   13.412843   Condominium     Private room             2        1.0
# 17904   13.421821     Apartment  Entire home/apt             2        1.0
# 20858   13.407615          Loft  Entire home/apt             4        1.0
# 21869   13.434620     Apartment  Entire home/apt             4        1.0
# 22415   13.428501     Apartment  Entire home/apt             4        1.0
# 22677   13.405577     Apartment  Entire home/apt             5        1.0
# 23834   13.379748   Condominium  Entire home/apt             4        1.0
# 24569   13.418084     Apartment  Entire home/apt             4        2.5
# 25653   13.419467     Apartment  Entire home/apt             4        2.5
# 26543   13.421377     Apartment  Entire home/apt             8        2.0
# 28156   13.405117     Apartment  Entire home/apt             2        1.0
# 28268   13.469948     Apartment  Entire home/apt             6        1.0
# 28711   13.434817     Apartment  Entire home/apt             3        NaN
# 29279   13.423883     Apartment  Entire home/apt             4        1.0
# 30295   13.422359     Apartment  Entire home/apt             8        1.0
# 31440   13.422453     Apartment     Private room             1        1.0
# 33043   13.357082     Apartment  Entire home/apt             4        1.0
# 35642   13.418228     Apartment  Entire home/apt             2        1.0
# 36480   13.302089     Apartment     Private room             1        0.0
# 37004   13.364813     Apartment     Private room             1        1.0
# 37052   13.404625     Apartment  Entire home/apt             2        1.0
# ...           ...           ...              ...           ...        ...
# 83183   13.424469     Apartment  Entire home/apt             2        1.0
# 83568   13.418910     Apartment  Entire home/apt             3        2.0
# 83614   13.417857     Apartment  Entire home/apt             5        1.5
# 85560   13.382299   Condominium  Entire home/apt             2        1.0
# 86514   13.441779     Apartment     Private room             2        1.0
# 87549   13.373974     Apartment     Private room             2        1.0
# 89102   13.409950     Apartment  Entire home/apt             4        1.0
# 91290   13.426191     Apartment  Entire home/apt             3        1.0
# 106290  13.431768     Apartment  Entire home/apt             3        1.0
# 106331  13.436699     Apartment  Entire home/apt             4        1.0
# 107968  13.342941     Apartment  Entire home/apt             2        1.0
# 109658  13.452067   Condominium  Entire home/apt             2        1.0
# 111579  13.409528     Apartment  Entire home/apt             2        1.0
# 114763  13.353250     Apartment  Entire home/apt             6        1.0
# 115576  13.397858         House  Entire home/apt             4        1.0
# 116832  13.396194     Apartment  Entire home/apt             2        1.0
# 117649  13.442649     Apartment  Entire home/apt             4        1.0
# 121888  13.463996     Apartment  Entire home/apt             4        1.0
# 125349  13.635283    Guesthouse  Entire home/apt             4        1.0
# 127708  13.410990     Apartment  Entire home/apt             2        1.0
# 128827  13.461193     Apartment  Entire home/apt             3        1.0
# 135097  13.346918     Apartment  Entire home/apt             6        1.0
# 138955  13.376910     Apartment  Entire home/apt             4        NaN
# 139769  13.391946     Apartment     Private room             2        1.0
# 143605  13.424371     Apartment  Entire home/apt             4        1.0
# 145249  13.461221          Loft     Private room             3        1.0
# 147946  13.408517     Apartment  Entire home/apt             2        1.0
# 149849  13.402598     Apartment     Private room             4        1.0
# 151249  13.416795     Apartment  Entire home/apt             4        1.0
# 153015  13.418254     Apartment     Private room             2        1.0
#
#         bedrooms                                          amenities  \
# id
# 2015         1.0  {TV,"Cable TV",Wifi,Kitchen,Gym,Heating,"Famil...
# 2695         1.0  {Wifi,Kitchen,Elevator,Heating,Washer,Essentia...
# 3176         1.0  {Internet,Wifi,Kitchen,"Buzzer/wireless interc...
# 3309         1.0  {Internet,Wifi,"Pets allowed","Pets live on th...
# 7071         1.0  {Wifi,Heating,"Family/kid friendly",Essentials...
# 9991         4.0  {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...
# 14325        0.0  {TV,Internet,Wifi,Kitchen,"Buzzer/wireless int...
# 16401        1.0  {TV,"Cable TV",Internet,Wifi,Kitchen,"Smoking ...
# 16644        1.0  {TV,Wifi,Kitchen,"Buzzer/wireless intercom",He...
# 17409        1.0  {TV,Internet,Wifi,Kitchen,"Paid parking off pr...
# 17904        NaN  {TV,Wifi,Kitchen,"Free street parking","Buzzer...
# 20858        2.0  {TV,Wifi,Kitchen,Elevator,"Indoor fireplace",H...
# 21869        1.0  {TV,Internet,Wifi,Kitchen,"Buzzer/wireless int...
# 22415        2.0  {"Cable TV",Internet,Wifi,Kitchen,"Pets allowe...
# 22677        1.0  {TV,Internet,Wifi,"Wheelchair accessible",Kitc...
# 23834        1.0  {TV,Wifi,Kitchen,"Free street parking",Heating...
# 24569        2.0  {TV,"Cable TV",Internet,Wifi,"Wheelchair acces...
# 25653        2.0  {TV,"Cable TV",Internet,Wifi,"Wheelchair acces...
# 26543        2.0  {TV,Internet,Wifi,Kitchen,"Free street parking...
# 28156        0.0  {TV,Internet,Wifi,Kitchen,"Buzzer/wireless int...
# 28268        2.0  {TV,Internet,Wifi,Kitchen,"Free parking on pre...
# 28711        1.0                                                 {}
# 29279        2.0  {TV,Wifi,Kitchen,"Paid parking off premises",H...
# 30295        2.0  {TV,"Cable TV",Internet,Wifi,"Wheelchair acces...
# 31440        1.0  {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...
# 33043        1.0  {Wifi,Kitchen,"Free street parking",Heating,"F...
# 35642        1.0  {TV,Wifi,Kitchen,Heating,Washer,Dryer,Microwav...
# 36480        1.0  {Heating,Essentials,Hangers,"Hair dryer",Iron,...
# 37004        1.0  {"Cable TV",Wifi,Kitchen,"Smoking allowed","Pe...
# 37052        1.0  {Wifi,Kitchen,Heating,"Family/kid friendly",Wa...
# ...          ...                                                ...
# 83183        1.0  {TV,Internet,Wifi,Kitchen,"Paid parking off pr...
# 83568        1.0  {TV,"Cable TV",Internet,Wifi,Kitchen,Elevator,...
# 83614        2.0  {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...
# 85560        1.0  {TV,Wifi,Kitchen,"Free street parking","Buzzer...
# 86514        1.0  {Wifi,Kitchen,"Buzzer/wireless intercom",Heati...
# 87549        1.0  {TV,Internet,Wifi,"Free street parking",Heatin...
# 89102        1.0  {Internet,Wifi,"Wheelchair accessible",Kitchen...
# 91290        1.0  {Internet,Wifi,Kitchen,"Buzzer/wireless interc...
# 106290       1.0  {TV,"Cable TV",Internet,Wifi,Kitchen,"Free str...
# 106331       1.0  {Internet,Wifi,Kitchen,"Paid parking off premi...
# 107968       1.0  {TV,"Cable TV",Internet,Wifi,Kitchen,Elevator,...
# 109658       1.0  {Internet,Wifi,Kitchen,"Free street parking","...
# 111579       1.0  {TV,Internet,Wifi,Kitchen,"Buzzer/wireless int...
# 114763       3.0  {TV,Internet,Wifi,"Wheelchair accessible",Kitc...
# 115576       2.0  {TV,Wifi,Kitchen,"Pets live on this property",...
# 116832       2.0  {Internet,Wifi,Kitchen,"Buzzer/wireless interc...
# 117649       1.0  {TV,Internet,Wifi,Kitchen,"Free street parking...
# 121888       1.0  {TV,"Cable TV",Internet,Wifi,Kitchen,"Smoking ...
# 125349       1.0  {TV,"Cable TV",Wifi,Kitchen,"Free street parki...
# 127708       1.0  {TV,"Cable TV",Internet,Wifi,Kitchen,"Pets all...
# 128827       1.0  {TV,Internet,Wifi,Kitchen,"Paid parking off pr...
# 135097       3.0  {TV,Wifi,Kitchen,"Paid parking off premises","...
# 138955       2.0  {Internet,Wifi,Kitchen,"Buzzer/wireless interc...
# 139769       1.0  {TV,Internet,Wifi,Kitchen,"Pets allowed","Buzz...
# 143605       1.0  {TV,Internet,Wifi,Kitchen,"Pets allowed","Free...
# 145249       1.0  {TV,Wifi,Kitchen,"Paid parking off premises",E...
# 147946       1.0  {TV,"Cable TV",Internet,Wifi,Kitchen,"Buzzer/w...
# 149849       2.0  {TV,Internet,Wifi,Kitchen,"Smoking allowed","P...
# 151249       1.0  {TV,"Cable TV",Internet,Wifi,Kitchen,"Pets liv...
# 153015       1.0  {Wifi,Kitchen,"Paid parking off premises","Smo...
#
#         square_feet  price cleaning_fee security_deposit extra_people  \
# id
# 2015            NaN   60.0       $30.00          $200.00       $28.00
# 2695            NaN   17.0        $0.00            $0.00        $0.00
# 3176          720.0   90.0       $50.00          $200.00       $20.00
# 3309            0.0   26.0       $30.00          $250.00       $18.00
# 7071            NaN   42.0        $0.00            $0.00       $24.00
# 9991            NaN  180.0       $80.00          $400.00       $10.00
# 14325           NaN   70.0        $0.00          $500.00        $0.00
# 16401           NaN  120.0          NaN              NaN       $13.00
# 16644           0.0   90.0       $50.00          $500.00       $20.00
# 17409           NaN   45.0       $18.00            $0.00       $26.00
# 17904           NaN   49.0       $50.00            $0.00       $15.00
# 20858           NaN  129.0       $49.00          $500.00       $24.00
# 21869           NaN   70.0       $40.00          $500.00       $18.00
# 22415           0.0   98.0       $50.00          $300.00       $25.00
# 22677         753.0  160.0       $40.00          $150.00       $35.00
# 23834           NaN   65.0       $50.00          $500.00        $0.00
# 24569           NaN   90.0       $35.00          $200.00        $5.00
# 25653           NaN   90.0       $55.00          $200.00        $5.00
# 26543        1012.0  197.0       $50.00          $250.00       $40.00
# 28156           NaN   70.0          NaN        $1,660.00        $0.00
# 28268           0.0   90.0       $50.00          $200.00       $20.00
# 28711           NaN   60.0       $30.00              NaN       $10.00
# 29279           NaN  130.0       $80.00        $1,500.00        $0.00
# 30295           NaN  100.0       $40.00              NaN       $20.00
# 31440           NaN   44.0       $15.00          $100.00       $15.00
# 33043           0.0   62.0       $20.00            $0.00        $8.00
# 35642           0.0   55.0       $50.00        $1,000.00       $10.00
# 36480           NaN   40.0        $5.00          $500.00       $20.00
# 37004         646.0   25.0        $0.00            $0.00       $15.00
# 37052           0.0   52.0       $30.00          $100.00       $12.00
# ...             ...    ...          ...              ...          ...
# 83183           NaN   53.0       $20.00              NaN       $20.00
# 83568           0.0   70.0       $30.00            $0.00       $20.00
# 83614           NaN   92.0       $36.00          $190.00       $19.00
# 85560         484.0   75.0       $30.00              NaN        $0.00
# 86514           NaN   80.0       $40.00          $150.00       $10.00
# 87549           NaN   48.0       $25.00            $0.00       $10.00
# 89102           NaN  114.0       $40.00              NaN       $15.00
# 91290           NaN   60.0       $20.00              NaN        $0.00
# 106290        484.0   50.0       $45.00          $125.00       $30.00
# 106331          NaN   82.0       $50.00            $0.00        $5.00
# 107968          0.0   80.0       $35.00          $300.00       $25.00
# 109658          NaN   60.0       $25.00              NaN        $0.00
# 111579          NaN   70.0       $30.00            $0.00       $15.00
# 114763          NaN  130.0       $50.00            $0.00        $0.00
# 115576         65.0   69.0       $45.00              NaN       $15.00
# 116832        969.0   75.0       $20.00          $250.00        $0.00
# 117649        388.0   68.0       $25.00              NaN       $20.00
# 121888          NaN  125.0       $40.00              NaN       $10.00
# 125349          NaN   70.0       $25.00              NaN        $0.00
# 127708          NaN   89.0       $40.00              NaN       $15.00
# 128827          NaN   59.0       $30.00              NaN       $20.00
# 135097          NaN   96.0       $88.00            $0.00        $9.00
# 138955          NaN   75.0       $40.00              NaN       $10.00
# 139769          NaN   55.0        $0.00            $0.00        $5.00
# 143605          0.0   55.0       $40.00          $200.00       $15.00
# 145249          NaN   70.0       $40.00           $85.00       $10.00
# 147946          NaN   31.0        $0.00          $250.00        $0.00
# 149849          NaN   40.0       $20.00          $100.00       $25.00
# 151249          NaN   81.0       $80.00        $1,000.00       $20.00
# 153015          NaN   52.0       $20.00              NaN       $15.00
#
#         guests_included instant_bookable
# id
# 2015                  1                f
# 2695                  1                f
# 3176                  2                t
# 3309                  1                f
# 7071                  1                f
# 9991                  5                f
# 14325                 1                f
# 16401                 1                f
# 16644                 2                f
# 17409                 1                f
# 17904                 1                f
# 20858                 2                f
# 21869                 2                f
# 22415                 2                f
# 22677                 4                f
# 23834                 1                f
# 24569                 2                f
# 25653                 2                f
# 26543                 4                t
# 28156                 1                f
# 28268                 4                f
# 28711                 2                f
# 29279                 2                f
# 30295                 4                t
# 31440                 1                f
# 33043                 2                t
# 35642                 1                t
# 36480                 1                f
# 37004                 1                f
# 37052                 1                f
# ...                 ...              ...
# 83183                 1                f
# 83568                 2                f
# 83614                 1                t
# 85560                 1                t
# 86514                 1                f
# 87549                 1                t
# 89102                 2                f
# 91290                 1                f
# 106290                2                f
# 106331                2                f
# 107968                1                f
# 109658                2                f
# 111579                1                f
# 114763                1                f
# 115576                2                f
# 116832                1                f
# 117649                2                t
# 121888                2                f
# 125349                1                f
# 127708                2                f
# 128827                2                f
# 135097                3                t
# 138955                2                f
# 139769                1                f
# 143605                2                f
# 145249                1                t
# 147946                1                f
# 149849                2                t
# 151249                1                f
# 153015                2                f
#
# [100 rows x 17 columns]

# %%
(LS_new.pivot(columns = 'bedrooms', values = "price")
         .plot.hist(bins = 30, stacked = True))

# %%
sns.barplot(x = "bedrooms", y = "price", data =LS_new )

# %%
plt.figure(figsize = (12, 6))
sns.boxplot(x = 'bedrooms', y = 'price',  data = LS_new)
xt = plt.xticks(rotation=90)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(LS_new.groupby([
        'neighbourhood_group_cleansed', 'bedrooms']).price.mean().unstack(),annot=True, fmt=".0f")

# %%
(LS_new.pivot(columns = "room_type", values = "price")
         .plot.hist(bins = 30, stacked = False, alpha = 0.8))

# %%
sns.countplot( LS_new['room_type'] )

# %%
plt.figure(figsize = (12, 6))
sns.boxplot(x = 'neighbourhood_group_cleansed', y = 'price',  data = LS_new)
xt = plt.xticks(rotation=90)

# %%
sns.countplot( LS_new['neighbourhood_group_cleansed'] )

# %%
sns.violinplot('neighbourhood_group_cleansed', 'price', data = LS_new)
xt = plt.xticks(rotation=90)

# %%
sns.factorplot('neighbourhood_group_cleansed', 'price', data = LS_new, color = 'm', \
               estimator = np.median, size = 4.5,  aspect=1.35)
xt = plt.xticks(rotation=90)

# %%
#making heatmap for finding the correlation between variable
fig, ax = plt.subplots(figsize=(15,15)) 
sns.heatmap(LS_new[LS_new["room_type"] == "Entire home/apt"].corr(), annot=True)

# %%
plt.figure(figsize = (12, 6))
sns.boxplot(x = 'accommodates', y = 'price',  data = LS_new)
xt = plt.xticks(rotation=90)

# %%
sns.barplot(x = "square_feet", y = "price", data =LS_new )

# %%
LS_new.amenities = LS_new.amenities.str.replace("[{}]", "").str.replace('"', "")
LS_new['amenities'].head()
# Out:
# id
# 2015    TV,Cable TV,Wifi,Kitchen,Gym,Heating,Family/ki...
# 2695    Wifi,Kitchen,Elevator,Heating,Washer,Essential...
# 3176    Internet,Wifi,Kitchen,Buzzer/wireless intercom...
# 3309    Internet,Wifi,Pets allowed,Pets live on this p...
# 7071    Wifi,Heating,Family/kid friendly,Essentials,Sh...
# Name: amenities, dtype: object

# %%
# Create a count of most common amenities
Amenities = LS_new['amenities'].tolist()
Am = str(Amenities)
Am = Am.replace("[","")
Am = Am.replace("]","")
Am = Am.replace("'","")
Am = Am.replace(" Wifi","Wifi")
Am1 = str.split(Am,",")

#import counter 
from collections import Counter
Counter(Am1).most_common(20)
# Out:
# [('Wifi', 21339),
#  ('Heating', 21021),
#  ('Kitchen', 20730),
#  ('Essentials', 20156),
#  ('Washer', 18361),
#  ('Hair dryer', 14745),
#  ('Laptop friendly workspace', 14327),
#  ('Hangers', 13766),
#  ('Iron', 11075),
#  ('Shampoo', 10529),
#  (' TV', 9952),
#  ('Hot water', 9637),
#  ('Family/kid friendly', 8046),
#  ('Host greets you', 6616),
#  ('Smoke detector', 6356),
#  ('Buzzer/wireless intercom', 6077),
#  ('Lock on bedroom door', 5243),
#  ('Refrigerator', 5156),
#  ('Free street parking', 5151),
#  ('Dishes and silverware', 5031)]

# %%
LS_new['Wifi'] = LS_new.amenities.str.contains('Wifi')
LS_new['Heating'] = LS_new.amenities.str.contains('Heating')
LS_new['Kitchen'] = LS_new.amenities.str.contains('Kitchen')
LS_new['Essentials'] = LS_new.amenities.str.contains('Essentials')
LS_new['Washer'] = LS_new.amenities.str.contains('Washer')
LS_new['Hair dryer'] = LS_new.amenities.str.contains('Hair dryer')
LS_new['Laptop friendly workspace'] = LS_new.amenities.str.contains('Laptop friendly workspace')
LS_new['Hangers'] = LS_new.amenities.str.contains('Hangers')
LS_new['Iron'] = LS_new.amenities.str.contains('Iron')
LS_new['Shampoo'] = LS_new.amenities.str.contains('Shampoo')
LS_new['TV'] = LS_new.amenities.str.contains('TV')
LS_new['Hot water'] = LS_new.amenities.str.contains('Hot water')
LS_new['Family/kid friendly'] = LS_new.amenities.str.contains('Family/kid friendly')
LS_new['Host greets you'] = LS_new.amenities.str.contains('Host greets you')
LS_new['Smoke detector'] = LS_new.amenities.str.contains('Smoke detector')
LS_new['Buzzer/wireless intercom'] = LS_new.amenities.str.contains('Buzzer/wireless intercom')
LS_new['Lock on bedroom door'] = LS_new.amenities.str.contains('Lock on bedroom door')
LS_new['Refrigerator'] = LS_new.amenities.str.contains('Refrigerator')
LS_new['Free street parking'] = LS_new.amenities.str.contains('Free street parking')
LS_new['Dishes and silverware'] = LS_new.amenities.str.contains('Dishes and silverware')

# %%
LS_price_top20amenities = LS_new[['price', 'Wifi', 'Heating', 'Kitchen', 'Essentials', 'Washer', 'Hair dryer', 'Laptop friendly workspace', 'Hangers', 'Iron', 'Shampoo', 'TV', 'Hot water','Family/kid friendly', 'Host greets you', 'Smoke detector','Buzzer/wireless intercom','Lock on bedroom door', 'Refrigerator', 'Free street parking', 'Dishes and silverware']]

# %%
#making heatmap for finding the correlation between variable
fig, ax = plt.subplots(figsize=(15,15)) 
sns.heatmap(LS_price_top20amenities.corr(), annot=True)
